# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('insurance.csv')
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
sns.histplot(data=df,x='age',kde=True,bins=20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df,x='bmi',kde=True,bins=20)
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.histplot(data=df,x='children',kde=True,bins=20)
# Out:
# <Axes: xlabel='children', ylabel='Count'>

# %%
sns.boxplot(data=df,x='children',y='expenses')
# Out:
# <Axes: xlabel='children', ylabel='expenses'>

# %%
sns.boxplot(data=df,x='smoker',y='expenses')
# Out:
# <Axes: xlabel='smoker', ylabel='expenses'>

# %%
sns.boxplot(data=df,x='region',y='expenses')
# Out:
# <Axes: xlabel='region', ylabel='expenses'>

# %%
sns.countplot(data=df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df=df.drop_duplicates()

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
x=df[['age']]
y=df['expenses']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=25)

# %%
x_train.shape
# Out:
# (1069, 1)

# %%
y_test.shape
# Out:
# (268,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([242.56517177])

# %%
model.intercept_
# Out:
# np.float64(3769.4369646856703)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([15170.00003801, 16140.26072511, 15412.56520979, 14442.30452269,
#        16140.26072511,  8135.6100566 , 13957.17417915, 14684.86969447,
#        17838.21692752, 12259.21797674, 11531.52246142, 14442.30452269,
#         8378.17522837, 13957.17417915, 12016.65280497, 12986.91349206,
#         9348.43591546, 16625.39106865,  8863.30557192, 10318.69660255,
#        15412.56520979, 10561.26177433, 12016.65280497, 17838.21692752,
#        17110.5214122 , 14927.43486624, 15412.56520979, 14199.73935092,
#         8620.74040014, 19293.60795815, 15170.00003801,  8378.17522837,
#        11046.39211787, 13714.60900738, 17595.65175574, 17353.08658397,
#        17838.21692752, 10076.13143078, 15170.00003801, 17595.65175574,
#         9105.87074369, 14199.73935092,  8620.74040014, 12744.34832028,
#        13714.60900738,  9348.43591546, 10318.69660255, 19293.60795815,
#        16140.26072511,  8135.6100566 ,  8135.6100566 , 16140.26072511,
#        13472.0438356 , 16140.26072511, 14442.30452269, 15412.56520979,
#        13957.17417915, 15897.69555333, 10076.13143078,  8135.6100566 ,
#        16867.95624042, 16867.95624042, 13472.0438356 , 10803.8269461 ,
#         8135.6100566 , 10803.8269461 , 15655.13038156, 12744.34832028,
#         8378.17522837, 15897.69555333, 16140.26072511, 16382.82589688,
#        17353.08658397, 18323.34727106,  8378.17522837,  8378.17522837,
#         9591.00108724, 13714.60900738, 16140.26072511, 16382.82589688,
#         8135.6100566 , 19293.60795815, 14199.73935092, 12986.91349206,
#         8378.17522837,  9833.56625901, 18080.78209929, 10076.13143078,
#        18080.78209929, 19051.04278638,  8378.17522837, 19293.60795815,
#        13229.47866383, 14442.30452269,  8620.74040014, 18565.91244283,
#         8135.6100566 , 14442.30452269, 15412.56520979, 17353.08658397,
#        15170.00003801, 18080.78209929, 19293.60795815,  8378.17522837,
#         8135.6100566 , 14684.86969447,  8135.6100566 , 11774.08763319,
#         8863.30557192,  9833.56625901,  8620.74040014, 14684.86969447,
#        10803.8269461 , 16625.39106865,  9348.43591546, 10318.69660255,
#        12259.21797674, 14684.86969447, 16382.82589688, 10803.8269461 ,
#        14684.86969447, 14927.43486624, 16382.82589688, 19051.04278638,
#        16382.82589688, 10318.69660255, 19051.04278638, 15655.13038156,
#        11288.95728965,  9348.43591546, 12501.78314851, 17353.08658397,
#        16867.95624042, 12501.78314851, 10318.69660255,  9591.00108724,
#         9833.56625901, 18080.78209929, 15897.69555333, 18808.47761461,
#         8135.6100566 , 16382.82589688, 15412.56520979, 15655.13038156,
#         9105.87074369, 10076.13143078, 17595.65175574,  8378.17522837,
#        11288.95728965, 16382.82589688,  8135.6100566 ,  8135.6100566 ,
#        11288.95728965,  8378.17522837, 17110.5214122 , 12501.78314851,
#        10803.8269461 , 15170.00003801, 15412.56520979, 14927.43486624,
#        15412.56520979, 16867.95624042,  9833.56625901,  9348.43591546,
#        17595.65175574,  8620.74040014, 18565.91244283, 18323.34727106,
#        10561.26177433,  8135.6100566 ,  8378.17522837,  8135.6100566 ,
#        13714.60900738, 11046.39211787, 15897.69555333, 12744.34832028,
#        13957.17417915, 18323.34727106, 12259.21797674, 16867.95624042,
#        12744.34832028, 10803.8269461 ,  8135.6100566 , 16625.39106865,
#        10318.69660255, 11774.08763319, 14199.73935092, 14684.86969447,
#        17110.5214122 , 14442.30452269, 14199.73935092, 12501.78314851,
#        10803.8269461 ,  8378.17522837, 18565.91244283, 15170.00003801,
#        14199.73935092, 10318.69660255, 12016.65280497,  8863.30557192,
#        13229.47866383, 11288.95728965, 15412.56520979,  8378.17522837,
#        13714.60900738, 18323.34727106, 12259.21797674,  8378.17522837,
#         9105.87074369,  8378.17522837, 15170.00003801,  8378.17522837,
#         8620.74040014,  8135.6100566 , 17353.08658397, 12259.21797674,
#        18565.91244283, 15170.00003801, 14442.30452269, 13472.0438356 ,
#         9591.00108724, 16867.95624042, 11046.39211787, 11531.52246142,
#        11774.08763319, 13957.17417915, 11046.39211787, 15897.69555333,
#        16140.26072511, 13229.47866383,  9833.56625901, 18565.91244283,
#        12016.65280497, 12986.91349206, 18565.91244283, 13714.60900738,
#        11288.95728965,  8135.6100566 , 10803.8269461 , 10318.69660255,
#        10318.69660255, 13714.60900738, 13957.17417915, 17110.5214122 ,
#        19293.60795815,  8378.17522837,  9348.43591546, 13472.0438356 ,
#        13229.47866383,  9833.56625901,  8378.17522837, 12016.65280497,
#        13957.17417915, 12744.34832028, 15897.69555333, 12744.34832028,
#        10561.26177433,  8135.6100566 ,  8620.74040014, 18080.78209929,
#        12744.34832028, 11288.95728965, 11531.52246142, 18565.91244283,
#        15170.00003801, 10076.13143078, 13229.47866383, 12986.91349206])

# %%
plt.plot(x_test,y_pred)
plt.scatter(x_test,y_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print(mean_absolute_error(y_test,y_pred))
# Out:
# 9116.657516733074

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 128861058.65267788

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.12593246349669673

# %%
x=df.drop('expenses',axis=1)
x
# Out:
#       age     sex   bmi  children smoker     region
# 0      19  female  27.9         0    yes  southwest
# 1      18    male  33.8         1     no  southeast
# 2      28    male  33.0         3     no  southeast
# 3      33    male  22.7         0     no  northwest
# 4      32    male  28.9         0     no  northwest
# ...   ...     ...   ...       ...    ...        ...
# 1333   50    male  31.0         3     no  northwest
# 1334   18  female  31.9         0     no  northeast
# 1335   18  female  36.9         0     no  southeast
# 1336   21  female  25.8         0     no  southwest
# 1337   61  female  29.1         0    yes  northwest
#
# [1337 rows x 6 columns]

# %%
x=pd.get_dummies(x)
x
# Out:
#       age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0  16884.92     False        True             False
# 1      18  33.8         1   1725.55      True       False             False
# 2      28  33.0         3   4449.46      True       False             False
# 3      33  22.7         0  21984.47      True       False              True
# 4      32  28.9         0   3866.86      True       False              True
# ...   ...   ...       ...       ...       ...         ...               ...
# 1333   50  31.0         3  10600.55      True       False              True
# 1334   18  31.9         0   2205.98     False       False             False
# 1335   18  36.9         0   1629.83     False       False             False
# 1336   21  25.8         0   2007.95     False       False             False
# 1337   61  29.1         0  29141.36     False        True              True
#
#       region_southeast  region_southwest
# 0                False              True
# 1                 True             False
# 2                 True             False
# 3                False             False
# 4                False             False
# ...                ...               ...
# 1333             False             False
# 1334             False             False
# 1335              True             False
# 1336             False              True
# 1337             False             False
#
# [1337 rows x 9 columns]

# %%
y=df['expenses']

# %%
x=df.drop('expenses',axis=1)
x=pd.get_dummies(x)
y=df['expenses']
x_train,x_test,t_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
print(model.coef_)
print(model.intercept_)
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(r2_score(y_test,y_pred))
# Out:
# [   27.44082554   -75.16802135   263.45594383  -135.52011997
#    135.52011997  -426.90500033   426.90500033  1372.64315295
#   -511.71258485  1204.68640189 -2065.61696999]
# 14448.13013209958
# 8186.90944729556
# 121512306.8509331
# 0.060664302995469876

# %%
#age=20,bmi=28,sex=male,smoker=yes,region=northeast,children=2
model.predict(np.array([[20,28,2,0,1,0,1,1,0,0,0]]))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15354.22220601])

# %%
x
# Out:
#       age   bmi  children  sex_female  sex_male  smoker_no  smoker_yes  \
# 0      19  27.9         0        True     False      False        True
# 1      18  33.8         1       False      True       True       False
# 2      28  33.0         3       False      True       True       False
# 3      33  22.7         0       False      True       True       False
# 4      32  28.9         0       False      True       True       False
# ...   ...   ...       ...         ...       ...        ...         ...
# 1333   50  31.0         3       False      True       True       False
# 1334   18  31.9         0        True     False       True       False
# 1335   18  36.9         0        True     False       True       False
# 1336   21  25.8         0        True     False       True       False
# 1337   61  29.1         0        True     False      False        True
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# 1                False             False              True             False
# 2                False             False              True             False
# 3                False              True             False             False
# 4                False              True             False             False
# ...                ...               ...               ...               ...
# 1333             False              True             False             False
# 1334              True             False             False             False
# 1335             False             False              True             False
# 1336             False             False             False              True
# 1337             False              True             False             False
#
# [1337 rows x 11 columns]

# %%
df=pd.read_csv('fish.csv')
df
x=df.drop(['Species','Weight'],axis=1)
y=df['Weight']
r2=[]
r2_max=0
test=[0.05,0.1,0.15,0.2,0.25]
for i in test:
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=i,random_state=42)
    model=LinearRegression()
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    r2.append(r2_score(y_test,y_pred))
    if r2_score(y_test,y_pred)>r2_max:
        r2_max=r2_score(y_test,y_pred)
        y_ans=model.predict(np.array([[20,20,20,5,10]]))
print(y_ans)
plt.plot(test,r2)
# Out:
# [409.16098386]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x
# Out:
#      Length1  Length2  Length3   Height   Width
# 0       23.2     25.4     30.0  11.5200  4.0200
# 1       24.0     26.3     31.2  12.4800  4.3056
# 2       23.9     26.5     31.1  12.3778  4.6961
# 3       26.3     29.0     33.5  12.7300  4.4555
# 4       26.5     29.0     34.0  12.4440  5.1340
# ..       ...      ...      ...      ...     ...
# 154     11.5     12.2     13.4   2.0904  1.3936
# 155     11.7     12.4     13.5   2.4300  1.2690
# 156     12.1     13.0     13.8   2.2770  1.2558
# 157     13.2     14.3     15.2   2.8728  2.0672
# 158     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 5 columns]
